),
#  FileInfo(path='dbfs:/Volumes/angad_kumar91/fhir_healthcare_analytics_rawdataset/raw_fhir/Theresa98_Hilpert278_a01df3b5-e092-96a4-76ce-8fa15c22dfb1.json', name='Theresa98_Hilpert278_a01df3b5-e092-96a4-76ce-8fa15c22dfb1.json', size=583363, modificationTime=1765658173000),
#  FileInfo(path='dbfs:/Volumes/angad_kumar91/fhir_healthcare_analytics_rawdataset/raw_fhir/Timoteo39_Tamayo777_31138316-2dc2-c809-21e4-9f097666a14a.json', name='Timoteo39_Tamayo777_31138316-2dc2-c809-21e4-9f097666a14a.json', size=2480148, modificationTime=1765658181000),
#  FileInfo(path='dbfs:/Volumes/angad_kumar91/fhir_healthcare_analytics_rawdataset/raw_fhir/Timothy142_Nienow652_2bdd6aa2-69f7-839e-5924-1d8d6b0f4e1e.json', name='Timothy142_Nienow652_2bdd6aa2-69f7-839e-5924-1d8d6b0f4e1e.json', size=584169, modificationTime=1765658176000),
#  FileInfo(path='dbfs:/Volumes/angad_kumar91/fhir_healthcare_analytics_rawdataset/raw_fhir/Tomoko463_Bergstrom287_e6ccf48c-3e81-913d-b524-b51238580947.json', name='Tomoko463_Bergstrom287_e6ccf48c-3e81-913d-b524-b51238580947.json', size=2840965, modificationTime=1765658184000),
#  FileInfo(path='dbfs:/Volumes/angad_kumar91/fhir_healthcare_analytics_rawdataset/raw_fhir/Wai719_Baumbach677_2a7454d4-6b6d-bb33-d2f7-d4ab886d6012.json', name='Wai719_Baumbach677_2a7454d4-6b6d-bb33-d2f7-d4ab886d6012.json', size=2045627, modificationTime=1765658182000),
#  FileInfo(path='dbfs:/Volumes/angad_kumar91/fhir_healthcare_analytics_rawdataset/raw_fhir/Walker122_Yundt842_6564dee7-31b7-cbd3-4382-e6289c750110.json', name='Walker122_Yundt842_6564dee7-31b7-cbd3-4382-e6289c750110.json', size=4899087, modificationTime=1765658190000),
#  FileInfo(path='dbfs:/Volumes/angad_kumar91/fhir_healthcare_analytics_rawdataset/raw_fhir/Wally311_Bayer639_3988f353-3849-69a1-2780-a5c23bd44909.json', name='Wally311_Bayer639_3988f353-3849-69a1-2780-a5c23bd44909.json', size=3089261, modificationTime=1765658188000),
#  FileInfo(path='dbfs:/Volumes/angad_kumar91/fhir_healthcare_analytics_rawdataset/raw_fhir/Will178_Kemmer137_3f3c4fb3-c95a-58a8-72a7-acc2b0af61f5.json', name='Will178_Kemmer137_3f3c4fb3-c95a-58a8-72a7-acc2b0af61f5.json', size=1350627, modificationTime=1765658185000),
#  FileInfo(path='dbfs:/Volumes/angad_kumar91/fhir_healthcare_analytics_rawdataset/raw_fhir/Willis868_Torphy630_0bdd1a87-dca8-5164-8ec6-28cc7b17cfb9.json', name='Willis868_Torphy630_0bdd1a87-dca8-5164-8ec6-28cc7b17cfb9.json', size=834582, modificationTime=1765658186000),
#  FileInfo(path='dbfs:/Volumes/angad_kumar91/fhir_healthcare_analytics_rawdataset/raw_fhir/Wynona930_Schamberger479_edd959a2-e707-37e6-b5ab-3d38620178ae.json', name='Wynona930_Schamberger479_edd959a2-e707-37e6-b5ab-3d38620178ae.json', size=4578833, modificationTime=1765658191000),
#  FileInfo(path='dbfs:/Volumes/angad_kumar91/fhir_healthcare_analytics_rawdataset/raw_fhir/Yolanda648_Riojas420_41a39ee6-612c-5557-4471-723c44e7b414.json', name='Yolanda648_Riojas420_41a39ee6-612c-5557-4471-723c44e7b414.json', size=1236603, modificationTime=1765658188000),
#  FileInfo(path='dbfs:/Volumes/angad_kumar91/fhir_healthcare_analytics_rawdataset/raw_fhir/hospitalInformation1764786987259.json', name='hospitalInformation1764786987259.json', size=908977, modificationTime=1765658133000),
#  FileInfo(path='dbfs:/Volumes/angad_kumar91/fhir_healthcare_analytics_rawdataset/raw_fhir/practitionerInformation1764786987259.json', name='practitionerInformation1764786987259.json', size=953571, modificationTime=1765658167000)]

# %%
raw_df = spark.read \
    .option("multiLine", "true") \
    .json("/Volumes/angad_kumar91/fhir_healthcare_analytics_rawdataset/raw_fhir/*.json")

# %%
raw_df.printSchema()
# Out:
# root
#  |-- entry: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- fullUrl: string (nullable = true)
#  |    |    |-- request: struct (nullable = true)
#  |    |    |    |-- ifNoneExist: string (nullable = true)
#  |    |    |    |-- method: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- resource: struct (nullable = true)
#  |    |    |    |-- abatementDateTime: string (nullable = true)
#  |    |    |    |-- active: boolean (nullable = true)
#  |    |    |    |-- activity: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- detail: struct (nullable = true)
#  |    |    |    |    |    |    |-- code: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |    |-- location: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |-- reasonCode: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |    |-- reasonReference: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |    |    |    |-- status: string (nullable = true)
#  |    |    |    |-- address: string (nullable = true)
#  |    |    |    |-- addresses: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- agent: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- onBehalfOf: struct (nullable = true)
#  |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |    |    |-- type: struct (nullable = true)
#  |    |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |-- who: struct (nullable = true)
#  |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- author: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- authoredOn: string (nullable = true)
#  |    |    |    |-- billablePeriod: struct (nullable = true)
#  |    |    |    |    |-- end: string (nullable = true)
#  |    |    |    |    |-- start: string (nullable = true)
#  |    |    |    |-- birthDate: string (nullable = true)
#  |    |    |    |-- careTeam: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- provider: struct (nullable = true)
#  |    |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |    |    |-- role: struct (nullable = true)
#  |    |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- sequence: long (nullable = true)
#  |    |    |    |-- category: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- claim: struct (nullable = true)
#  |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- class: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |-- clinicalStatus: struct (nullable = true)
#  |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |-- code: string (nullable = true)
#  |    |    |    |-- communication: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- language: struct (nullable = true)
#  |    |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |-- component: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- code: struct (nullable = true)
#  |    |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |-- valueCodeableConcept: struct (nullable = true)
#  |    |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |-- valueQuantity: struct (nullable = true)
#  |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |-- unit: string (nullable = true)
#  |    |    |    |    |    |    |-- value: double (nullable = true)
#  |    |    |    |    |    |-- valueString: string (nullable = true)
#  |    |    |    |-- contained: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- beneficiary: struct (nullable = true)
#  |    |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |-- intent: string (nullable = true)
#  |    |    |    |    |    |-- payor: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |-- performer: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |    |    |-- requester: struct (nullable = true)
#  |    |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |    |    |-- resourceType: string (nullable = true)
#  |    |    |    |    |    |-- status: string (nullable = true)
#  |    |    |    |    |    |-- subject: struct (nullable = true)
#  |    |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |    |    |-- type: struct (nullable = true)
#  |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |-- content: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- attachment: struct (nullable = true)
#  |    |    |    |    |    |    |-- contentType: string (nullable = true)
#  |    |    |    |    |    |    |-- data: string (nullable = true)
#  |    |    |    |    |    |-- format: struct (nullable = true)
#  |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |-- context: struct (nullable = true)
#  |    |    |    |    |-- encounter: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |    |-- period: struct (nullable = true)
#  |    |    |    |    |    |-- end: string (nullable = true)
#  |    |    |    |    |    |-- start: string (nullable = true)
#  |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- created: string (nullable = true)
#  |    |    |    |-- criticality: string (nullable = true)
#  |    |    |    |-- custodian: struct (nullable = true)
#  |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- date: string (nullable = true)
#  |    |    |    |-- deceasedDateTime: string (nullable = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |    |    |-- deviceName: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- diagnosis: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- diagnosisReference: struct (nullable = true)
#  |    |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |    |    |-- sequence: long (nullable = true)
#  |    |    |    |    |    |-- type: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |-- distinctIdentifier: string (nullable = true)
#  |    |    |    |-- dosage: struct (nullable = true)
#  |    |    |    |    |-- dose: struct (nullable = true)
#  |    |    |    |    |    |-- value: double (nullable = true)
#  |    |    |    |    |-- rateQuantity: struct (nullable = true)
#  |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |-- dosageInstruction: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- additionalInstruction: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |-- asNeededBoolean: boolean (nullable = true)
#  |    |    |    |    |    |-- doseAndRate: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- doseQuantity: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- value: double (nullable = true)
#  |    |    |    |    |    |    |    |-- type: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- sequence: long (nullable = true)
#  |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |-- timing: struct (nullable = true)
#  |    |    |    |    |    |    |-- repeat: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- frequency: long (nullable = true)
#  |    |    |    |    |    |    |    |-- period: double (nullable = true)
#  |    |    |    |    |    |    |    |-- periodUnit: string (nullable = true)
#  |    |    |    |-- effectiveDateTime: string (nullable = true)
#  |    |    |    |-- encounter: struct (nullable = true)
#  |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- expirationDate: string (nullable = true)
#  |    |    |    |-- extension: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- extension: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |    |-- valueCoding: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |    |-- valueString: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |-- valueAddress: struct (nullable = true)
#  |    |    |    |    |    |    |-- city: string (nullable = true)
#  |    |    |    |    |    |    |-- country: string (nullable = true)
#  |    |    |    |    |    |    |-- state: string (nullable = true)
#  |    |    |    |    |    |-- valueCode: string (nullable = true)
#  |    |    |    |    |    |-- valueDecimal: double (nullable = true)
#  |    |    |    |    |    |-- valueInteger: long (nullable = true)
#  |    |    |    |    |    |-- valueString: string (nullable = true)
#  |    |    |    |-- facility: struct (nullable = true)
#  |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- gender: string (nullable = true)
#  |    |    |    |-- hospitalization: struct (nullable = true)
#  |    |    |    |    |-- dischargeDisposition: struct (nullable = true)
#  |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |-- id: string (nullable = true)
#  |    |    |    |-- identifier: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- type: struct (nullable = true)
#  |    |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |-- use: string (nullable = true)
#  |    |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- insurance: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- coverage: struct (nullable = true)
#  |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |    |    |-- focal: boolean (nullable = true)
#  |    |    |    |    |    |-- sequence: long (nullable = true)
#  |    |    |    |-- insurer: struct (nullable = true)
#  |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |-- intent: string (nullable = true)
#  |    |    |    |-- issued: string (nullable = true)
#  |    |    |    |-- item: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- adjudication: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- amount: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- currency: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- value: double (nullable = true)
#  |    |    |    |    |    |    |    |-- category: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- category: struct (nullable = true)
#  |    |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- diagnosisSequence: array (nullable = true)
#  |    |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |    |-- encounter: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |    |    |-- informationSequence: array (nullable = true)
#  |    |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |    |-- locationCodeableConcept: struct (nullable = true)
#  |    |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- net: struct (nullable = true)
#  |    |    |    |    |    |    |-- currency: string (nullable = true)
#  |    |    |    |    |    |    |-- value: double (nullable = true)
#  |    |    |    |    |    |-- procedureSequence: array (nullable = true)
#  |    |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |    |-- productOrService: struct (nullable = true)
#  |    |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |-- sequence: long (nullable = true)
#  |    |    |    |    |    |-- servicedPeriod: struct (nullable = true)
#  |    |    |    |    |    |    |-- end: string (nullable = true)
#  |    |    |    |    |    |    |-- start: string (nullable = true)
#  |    |    |    |-- location: string (nullable = true)
#  |    |    |    |-- lotNumber: string (nullable = true)
#  |    |    |    |-- managingOrganization: string (nullable = true)
#  |    |    |    |-- manufactureDate: string (nullable = true)
#  |    |    |    |-- maritalStatus: struct (nullable = true)
#  |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |-- medicationCodeableConcept: struct (nullable = true)
#  |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |-- medicationReference: struct (nullable = true)
#  |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- meta: struct (nullable = true)
#  |    |    |    |    |-- profile: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- mode: string (nullable = true)
#  |    |    |    |-- multipleBirthBoolean: boolean (nullable = true)
#  |    |    |    |-- multipleBirthInteger: long (nullable = true)
#  |    |    |    |-- name: string (nullable = true)
#  |    |    |    |-- numberOfInstances: long (nullable = true)
#  |    |    |    |-- numberOfSeries: long (nullable = true)
#  |    |    |    |-- occurrenceDateTime: string (nullable = true)
#  |    |    |    |-- onsetDateTime: string (nullable = true)
#  |    |    |    |-- organization: struct (nullable = true)
#  |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |-- identifier: struct (nullable = true)
#  |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- outcome: string (nullable = true)
#  |    |    |    |-- participant: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- individual: struct (nullable = true)
#  |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |    |    |-- member: struct (nullable = true)
#  |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |    |    |-- period: struct (nullable = true)
#  |    |    |    |    |    |    |-- end: string (nullable = true)
#  |    |    |    |    |    |    |-- start: string (nullable = true)
#  |    |    |    |    |    |-- role: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |-- type: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |-- patient: struct (nullable = true)
#  |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- payment: struct (nullable = true)
#  |    |    |    |    |-- amount: struct (nullable = true)
#  |    |    |    |    |    |-- currency: string (nullable = true)
#  |    |    |    |    |    |-- value: double (nullable = true)
#  |    |    |    |-- performedPeriod: struct (nullable = true)
#  |    |    |    |    |-- end: string (nullable = true)
#  |    |    |    |    |-- start: string (nullable = true)
#  |    |    |    |-- performer: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- period: struct (nullable = true)
#  |    |    |    |    |-- end: string (nullable = true)
#  |    |    |    |    |-- start: string (nullable = true)
#  |    |    |    |-- physicalType: struct (nullable = true)
#  |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |-- position: struct (nullable = true)
#  |    |    |    |    |-- latitude: double (nullable = true)
#  |    |    |    |    |-- longitude: double (nullable = true)
#  |    |    |    |-- practitioner: struct (nullable = true)
#  |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |-- identifier: struct (nullable = true)
#  |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- prescription: struct (nullable = true)
#  |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- presentedForm: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- contentType: string (nullable = true)
#  |    |    |    |    |    |-- data: string (nullable = true)
#  |    |    |    |-- primarySource: boolean (nullable = true)
#  |    |    |    |-- priority: struct (nullable = true)
#  |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |-- procedure: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- procedureReference: struct (nullable = true)
#  |    |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |    |    |-- sequence: long (nullable = true)
#  |    |    |    |-- procedureCode: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |-- provider: struct (nullable = true)
#  |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- reaction: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- manifestation: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |-- severity: string (nullable = true)
#  |    |    |    |-- reasonCode: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |-- reasonReference: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- recorded: string (nullable = true)
#  |    |    |    |-- recordedDate: string (nullable = true)
#  |    |    |    |-- referral: struct (nullable = true)
#  |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- requester: struct (nullable = true)
#  |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- resourceType: string (nullable = true)
#  |    |    |    |-- result: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- serialNumber: string (nullable = true)
#  |    |    |    |-- series: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- bodySite: struct (nullable = true)
#  |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- instance: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- number: long (nullable = true)
#  |    |    |    |    |    |    |    |-- sopClass: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |    |    |-- uid: string (nullable = true)
#  |    |    |    |    |    |-- modality: struct (nullable = true)
#  |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- number: long (nullable = true)
#  |    |    |    |    |    |-- numberOfInstances: long (nullable = true)
#  |    |    |    |    |    |-- started: string (nullable = true)
#  |    |    |    |    |    |-- uid: string (nullable = true)
#  |    |    |    |-- serviceProvider: struct (nullable = true)
#  |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- specialty: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |-- started: string (nullable = true)
#  |    |    |    |-- status: string (nullable = true)
#  |    |    |    |-- subject: struct (nullable = true)
#  |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- suppliedItem: struct (nullable = true)
#  |    |    |    |    |-- itemCodeableConcept: struct (nullable = true)
#  |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |-- quantity: struct (nullable = true)
#  |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |-- supportingInfo: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- category: struct (nullable = true)
#  |    |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- sequence: long (nullable = true)
#  |    |    |    |    |    |-- valueReference: struct (nullable = true)
#  |    |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- target: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- telecom: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- extension: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |    |-- valueBoolean: boolean (nullable = true)
#  |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- use: string (nullable = true)
#  |    |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- text: struct (nullable = true)
#  |    |    |    |    |-- div: string (nullable = true)
#  |    |    |    |    |-- status: string (nullable = true)
#  |    |    |    |-- total: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- udiCarrier: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- carrierHRF: string (nullable = true)
#  |    |    |    |    |    |-- deviceIdentifier: string (nullable = true)
#  |    |    |    |-- use: string (nullable = true)
#  |    |    |    |-- vaccineCode: struct (nullable = true)
#  |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |-- valueCodeableConcept: struct (nullable = true)
#  |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |-- valueQuantity: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |-- unit: string (nullable = true)
#  |    |    |    |    |-- value: double (nullable = true)
#  |    |    |    |-- valueString: string (nullable = true)
#  |    |    |    |-- verificationStatus: struct (nullable = true)
#  |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |-- system: string (nullable = true)
#  |-- resourceType: string (nullable = true)
#  |-- type: string (nullable = true)

# %%
from pyspark.sql.functions import current_timestamp, col

bronze_ready_df = raw_df \
    .withColumn("source_file", col("_metadata.file_path")) \
    .withColumn("ingest_time", current_timestamp())

# %%
# %sql
CREATE TABLE IF NOT EXISTS angad_kumar91.fhir_healthcare_analytics_bronze.fhir_bundle
USING DELTA;

# %%
bronze_ready_df.write \
    .format("delta") \
    .option("mergeSchema", "true") \
    .mode("append") \
    .saveAsTable(
        "angad_kumar91.fhir_healthcare_analytics_bronze.fhir_bundle"
    )

# %% [markdown]
# u

# %%
# %sql
DESCRIBE DETAIL angad_kumar91.fhir_healthcare_analytics_bronze.fhir_bundle;


DESCRIBE EXTENDED angad_kumar91.fhir_healthcare_analytics_bronze.fhir_bundle
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>entry</td><td>array<struct<fullUrl:string,request:struct<ifNoneExist:string,method:string,url:string>,resource:struct<abatementDateTime:string,active:boolean,activity:array<struct<detail:struct<code:struct<coding:array<struct<code:string,display:string,system:string>>,text:string>,location:struct<display:string>,reasonCode:array<struct<coding:array<struct<code:string,display:string,system:string>>,text:string>>,reasonReference:array<struct<reference:string>>,status:string>>>,address:string,addresses:array<struct<reference:string>>,agent:array<struct<onBehalfOf:struct<display:string,reference:string>,type:struct<coding:array<struct<code:string,display:string,system:string>>,text:string>,who:struct<display:string,reference:string>>>,author:array<struct<display:string,reference:string>>,authoredOn:string,billablePeriod:struct<end:string,start:string>,birthDate:string,careTeam:array<struct<provider:struct<reference:string>,reference:string,role:struct<coding:array<struct<code:string,display:string,system:string>>>,sequence:bigint>>,category:array<string>,claim:struct<reference:string>,class:struct<code:string,system:string>,clinicalStatus:struct<coding:array<struct<code:string,system:string>>>,code:string,communication:array<struct<language:struct<coding:array<struct<code:string,display:string,system:string>>,text:string>>>,component:array<struct<code:struct<coding:array<struct<code:string,display:string,system:string>>,text:string>,valueCodeableConcept:struct<coding:array<struct<code:string,display:string,system:string>>,text:string>,valueQuantity:struct<code:string,system:string,unit:string,value:double>,valueString:string>>,contained:array<struct<beneficiary:struct<reference:string>,id:string,intent:string,payor:array<struct<display:string>>,performer:array<struct<reference:string>>,requester:struct<reference:string>,resourceType:string,status:string,subject:struct<reference:string>,type:struct<text:string>>>,content:array<struct<attachment:struct<contentType:string,data:string>,format:struct<code:string,display:string,system:string>>>,context:struct<encounter:array<struct<reference:string>>,period:struct<end:string,start:string>,reference:string>,created:string,criticality:string,custodian:struct<display:string,reference:string>,date:string,... 85 more fields>>></td><td>null</td></tr><tr><td>resourceType</td><td>string</td><td>null</td></tr><tr><td>type</td><td>string</td><td>null</td></tr><tr><td>source_file</td><td>string</td><td>null</td></tr><tr><td>ingest_time</td><td>timestamp</td><td>null</td></tr><tr><td></td><td></td><td></td></tr><tr><td># Delta Statistics Columns</td><td></td><td></td></tr><tr><td>Column Names</td><td>resourceType, entry, ingest_time, type, source_file</td><td></td></tr><tr><td>Column Selection Method</td><td>first-32</td><td></td></tr><tr><td></td><td></td><td></td></tr><tr><td># Detailed Table Information</td><td></td><td></td></tr><tr><td>Catalog</td><td>angad_kumar91</td><td></td></tr><tr><td>Database</td><td>fhir_healthcare_analytics_bronze</td><td></td></tr><tr><td>Table</td><td>fhir_bundle</td><td></td></tr><tr><td>Created Time</td><td>Sat Dec 13 21:05:38 UTC 2025</td><td></td></tr><tr><td>Last Access</td><td>UNKNOWN</td><td></td></tr><tr><td>Created By</td><td>Spark </td><td></td></tr><tr><td>Statistics</td><td>28299135 bytes, 117 rows</td><td></td></tr><tr><td>Type</td><td>MANAGED</td><td></td></tr><tr><td>Location</td><td></td><td></td></tr><tr><td>Provider</td><td>delta</td><td></td></tr><tr><td>Owner</td><td>kumarangad91289@gmail.com</td><td></td></tr><tr><td>Is_managed_location</td><td>true</td><td></td></tr><tr><td>Predictive Optimization</td><td>ENABLE (inherited from METASTORE metastore_aws_us_east_2)</td><td></td></tr><tr><td>Table Properties</td><td>[delta.enableDeletionVectors=true,delta.en ...

# %%
# Using python to do the same as above
display(
    spark.sql(
        "DESCRIBE DETAIL angad_kumar91.fhir_healthcare_analytics_bronze.fhir_bundle"
    )
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>format</th><th>id</th><th>name</th><th>description</th><th>location</th><th>createdAt</th><th>lastModified</th><th>partitionColumns</th><th>clusteringColumns</th><th>numFiles</th><th>sizeInBytes</th><th>properties</th><th>minReaderVersion</th><th>minWriterVersion</th><th>tableFeatures</th><th>statistics</th><th>clusterByAuto</th></tr></thead><tbody><tr><td>delta</td><td>a93c7bea-f5fd-413e-920c-37a9248a57c9</td><td>angad_kumar91.fhir_healthcare_analytics_bronze.fhir_bundle</td><td>null</td><td></td><td>2025-12-13T21:05:37.472Z</td><td>2025-12-13T21:26:38.000Z</td><td>List()</td><td>List()</td><td>8</td><td>28299135</td><td>Map(delta.enableDeletionVectors -> true, delta.writePartitionColumnsToParquet -> true, delta.enableRowTracking -> true, delta.rowTracking.materializedRowCommitVersionColumnName -> _row-commit-version-col-7cb48660-74f1-4e2c-a269-f3d7fe7a344d, delta.rowTracking.materializedRowIdColumnName -> _row-id-col-b85bf714-66ae-410e-aaa1-e37cdb4f34cc)</td><td>3</td><td>7</td><td>List(appendOnly, deletionVectors, domainMetadata, invariants, rowTracking)</td><td>Map(numRowsDeletedByDeletionVectors -> 0, numDeletionVectors -> 0)</td><td>false</td></tr></tbody></table></div>

# %%
# %sql
SELECT COUNT(*) 
FROM angad_kumar91.fhir_healthcare_analytics_bronze.fhir_bundle;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>COUNT(*)</th></tr></thead><tbody><tr><td>117</td></tr></tbody></table></div>

# %% [markdown]
# ### What needs SMALL correction / confirmation for Unity Catalog
#
# 1️⃣ STEP 2 – Querying Bronze table (✅ OK)
#
# ✔ Works in Unity Catalog
# ✔ Confirms metadata
# ✔ No change needed

# %%
# %sql
SELECT
  resourceType,
  type,
  source_file,
  ingest_time
FROM angad_kumar91.fhir_healthcare_analytics_bronze.fhir_bundle
LIMIT 5;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>resourceType</th><th>type</th><th>source_file</th><th>ingest_time</th></tr></thead><tbody><tr><td>Bundle</td><td>transaction</td><td>dbfs:/Volumes/angad_kumar91/fhir_healthcare_analytics_rawdataset/raw_fhir/Adela471_Danica886_Schmitt836_0c1a1859-29c7-4f11-f21c-20a7099e8613.json</td><td>2025-12-13T21:26:30.399Z</td></tr><tr><td>Bundle</td><td>transaction</td><td>dbfs:/Volumes/angad_kumar91/fhir_healthcare_analytics_rawdataset/raw_fhir/Adriana394_Almaraz628_d00420ac-9a07-66dc-ee93-d2e3e9bbf23e.json</td><td>2025-12-13T21:26:30.399Z</td></tr><tr><td>Bundle</td><td>transaction</td><td>dbfs:/Volumes/angad_kumar91/fhir_healthcare_analytics_rawdataset/raw_fhir/Agustín529_Rivas297_6547940c-38ea-67f0-54d1-d132440c8cc9.json</td><td>2025-12-13T21:26:30.399Z</td></tr><tr><td>Bundle</td><td>transaction</td><td>dbfs:/Volumes/angad_kumar91/fhir_healthcare_analytics_rawdataset/raw_fhir/Alfonzo975_Casper496_fb62c08e-8900-5fb2-8a98-af95f64125ff.json</td><td>2025-12-13T21:26:30.399Z</td></tr><tr><td>Bundle</td><td>transaction</td><td>dbfs:/Volumes/angad_kumar91/fhir_healthcare_analytics_rawdataset/raw_fhir/Amado512_Raynor401_258041a6-bcb2-807e-65ee-c3e45e908d0b.json</td><td>2025-12-13T21:26:30.399Z</td></tr></tbody></table></div>

# %% [markdown]
# 2️⃣ STEP 3 – Inspect ENTRY array (✅ OK)
#
#
# ✔ Correct
# ✔ Unity Catalog compatible
# ✔ No change needed

# %%
bronze_df = spark.table(
    "angad_kumar91.fhir_healthcare_analytics_bronze.fhir_bundle"
)

bronze_df.selectExpr("size(entry) as resource_count").show(10)
# Out:
# +--------------+
# |resource_count|
# +--------------+
# |           440|
# |          2455|
# |           358|
# |          1060|
# |           398|
# |           309|
# |           480|
# |           758|
# |           674|
# |           843|
# +--------------+
# only showing top 10 rows

# %% [markdown]
# 3️⃣ STEP 4 – Explode ENTRY temporarily (✅ OK)
#
#
# ✔ Correct
# ✔ Temporary DataFrame only
# ✔ No storage
# ✔ No UC issues

# %%
from pyspark.sql.functions import explode, col

exploded_df = bronze_df \
    .select(
        col("source_file"),
        col("ingest_time"),
        explode("entry").alias("entry")
    )

# %% [markdown]
# 4️⃣ STEP 5 – Identify resource types (✅ OK)
#
#
# ✔ Correct
# ✔ Confirms FHIR event-based design
# ✔ No change needed

# %%
resource_distribution = exploded_df \
    .select(col("entry.resource.resourceType").alias("resource_type")) \
    .groupBy("resource_type") \
    .count() \
    .orderBy("count", ascending=False)

resource_distribution.show(truncate=False)
# Out:
# +------------------------+-----+
# |resource_type           |count|
# +------------------------+-----+
# |Observation             |64987|
# |Procedure               |20153|
# |DiagnosticReport        |14488|
# |Claim                   |12902|
# |ExplanationOfBenefit    |12902|
# |Encounter               |7095 |
# |DocumentReference       |7095 |
# |MedicationRequest       |5807 |
# |Condition               |4516 |
# |SupplyDelivery          |2844 |
# |Immunization            |1582 |
# |MedicationAdministration|1480 |
# |Medication              |1480 |
# |Device                  |678  |
# |ImagingStudy            |631  |
# |CareTeam                |392  |
# |CarePlan                |392  |
# |Location                |290  |
# |Organization            |289  |
# |Practitioner            |289  |
# +------------------------+-----+
# only showing top 20 rows

# %% [markdown]
# 5️⃣ STEP 6 – Repetition per patient (✅ OK)
#
# ✔ Correct
# ✔ This is proper Bronze data-quality validation
# ✔ No change needed

# %%
per_patient_resources = exploded_df \
    .groupBy("source_file", "entry.resource.resourceType") \
    .count() \
    .orderBy("source_file")

per_patient_resources.show(20, truncate=False)
# Out:
# +-------------------------------------------------------------------------------------------------------------------------------------------------+------------------------+-----+
# |source_file                                                                                                                                      |resourceType            |count|
# +-------------------------------------------------------------------------------------------------------------------------------------------------+------------------------+-----+
# |dbfs:/Volumes/angad_kumar91/fhir_healthcare_analytics_rawdataset/raw_fhir/Adela471_Danica886_Schmitt836_0c1a1859-29c7-4f11-f21c-20a7099e8613.json|MedicationAdministration|1    |
# |dbfs:/Volumes/angad_kumar91/fhir_healthcare_analytics_rawdataset/raw_fhir/Adela471_Danica886_Schmitt836_0c1a1859-29c7-4f11-f21c-20a7099e8613.json|DocumentReference       |49   |
# |dbfs:/Volumes/angad_kumar91/fhir_healthcare_analytics_rawdataset/raw_fhir/Adela471_Danica886_Schmitt836_0c1a1859-29c7-4f11-f21c-20a7099e8613.json|Observation             |86   |
# |dbfs:/Volumes/angad_kumar91/fhir_healthcare_analytics_rawdataset/raw_fhir/Adela471_Danica886_Schmitt836_0c1a1859-29c7-4f11-f21c-20a7099e8613.json|CarePlan                |5    |
# |dbfs:/Volumes/angad_kumar91/fhir_healthcare_analytics_rawdataset/raw_fhir/Adela471_Danica886_Schmitt836_0c1a1859-29c7-4f11-f21c-20a7099e8613.json|SupplyDelivery          |3    |
# |dbfs:/Volumes/angad_kumar91/fhir_healthcare_analytics_rawdataset/raw_fhir/Adela471_Danica886_Schmitt836_0c1a1859-29c7-4f11-f21c-20a7099e8613.json|Patient                 |1    |
# |dbfs:/Volumes/angad_kumar91/fhir_healthcare_analytics_rawdataset/raw_fhir/Adela471_Danica886_Schmitt836_0c1a1859-29c7-4f11-f21c-20a7099e8613.json|ImagingStudy            |1    |
# |dbfs:/Volumes/angad_kumar91/fhir_healthcare_analytics_rawdataset/raw_fhir/Adela471_Danica886_Schmitt836_0c1a1859-29c7-4f11-f21c-20a7099e8613.json|MedicationRequest       |6    |
# |dbfs:/Volumes/angad_kumar91/fhir_healthcare_analytics_rawdataset/raw_fhir/Adela471_Danica886_Schmitt836_0c1a1859-29c7-4f11-f21c-20a7099e8613.json|Procedure               |181  |
# |dbfs:/Volumes/angad_kumar91/fhir_healthcare_analytics_rawdataset/raw_fhir/Adela471_Danica886_Schmitt836_0c1a1859-29c7-4f11-f21c-20a7099e8613.json|Condition               |21   |
# |dbfs:/Volumes/angad_kumar91/fhir_healthcare_analytics_rawdataset/raw_fhir/Adela471_Danica886_Schmitt836_0c1a1859-29c7-4f11-f21c-20a7099e8613.json|Claim                   |55   |
# |dbfs:/Volumes/angad_kumar91/fhir_healthcare_analytics_rawdataset/raw_fhir/Adela471_Danica886_Schmitt836_0c1a1859-29c7-4f11-f21c-20a7099e8613.json|Medication              |1    |
# |dbfs:/Volumes/angad_kumar91/fhir_healthcare_analytics_rawdataset/raw_fhir/Adela471_Danica886_Schmitt836_0c1a1859-29c7-4f11-f21c-20a7099e8613.json|Encounter               |49   |
# |dbfs:/Volumes/angad_kumar91/fhir_healthcare_analytics_rawdataset/raw_fhir/Adela471_Danica886_Schmitt836_0c1a1859-29c7-4f11-f21c-20a7099e8613.json|Immunization            |7    |
# |dbfs:/Volumes/angad_kumar91/fhir_healthcare_analytics_rawdataset/raw_fhir/Adela471_Danica886_Schmitt836_0c1a1859-29c7-4f11-f21c-20a7099e8613.json|CareTeam                |5    |
# |dbfs:/Volumes/angad_kumar91/fhir_healthcare_analytics_rawdataset/raw_fhir/Adela471_Danica886_Schmitt836_0c1a1859-29c7-4f11-f21c-20a7099e8613.json|ExplanationOfBenefit    |55   |
# |dbfs:/Volumes/angad_kumar91/fhir_healthcare_analytics_rawdataset/raw_fhir/Adela471_Danica886_Schmitt836_0c1a1859-29c7-4f11-f21c-20a7099e8613.json|Device                  |1    |
# |dbfs:/Volumes/angad_kumar91/fhir_healthcare_analytics_rawdataset/raw_fhir/Adela471_Danica886_Schmitt836_0c1a1859-29c7-4f11-f21c-20a7099e8613.json|DiagnosticReport        |62   |
# |dbfs:/Volumes/angad_kumar91/fhir_healthcare_analytics_rawdataset/raw_fhir/Adela471_Danica886_Schmitt836_0c1a1859-29c7-4f11-f21c-20a7099e8613.json|Provenance              |1    |
# |dbfs:/Volumes/angad_kumar91/fhir_healthcare_analytics_rawdataset/raw_fhir/Adriana394_Almaraz628_d00420ac-9a07-66dc-ee93-d2e3e9bbf23e.json        |Encounter               |35   |
# +-------------------------------------------------------------------------------------------------------------------------------------------------+------------------------+-----+
# only showing top 20 rows

# %% [markdown]
# 6️⃣ STEP 7 – Validate FHIR references (⚠️ small safety fix)
#
# Your code (works, but can error if field missing)

# %%
exploded_df.select(
    col("entry.resource.resourceType"),
    col("entry.resource.subject.reference"),
    col("entry.resource.encounter.reference")
).show(20, truncate=False)
# Out:
# +--------------------+---------------------------------------------+---------------------------------------------+
# |resourceType        |reference                                    |reference                                    |
# +--------------------+---------------------------------------------+---------------------------------------------+
# |Patient             |NULL                                         |NULL                                         |
# |Encounter           |urn:uuid:473282d3-65db-fb8e-9913-af83bbf2595f|NULL                                         |
# |CareTeam            |urn:uuid:473282d3-65db-fb8e-9913-af83bbf2595f|urn:uuid:473282d3-65db-fb8e-043f-ee22ffdc488c|
# |CarePlan            |urn:uuid:473282d3-65db-fb8e-9913-af83bbf2595f|urn:uuid:473282d3-65db-fb8e-043f-ee22ffdc488c|
# |DiagnosticReport    |urn:uuid:473282d3-65db-fb8e-9913-af83bbf2595f|urn:uuid:473282d3-65db-fb8e-043f-ee22ffdc488c|
# |DocumentReference   |urn:uuid:473282d3-65db-fb8e-9913-af83bbf2595f|NULL                                         |
# |Claim               |NULL                                         |NULL                                         |
# |ExplanationOfBenefit|NULL                                         |NULL                                         |
# |Encounter           |urn:uuid:473282d3-65db-fb8e-9913-af83bbf2595f|NULL                                         |
# |AllergyIntolerance  |NULL                                         |NULL                                         |
# |AllergyIntolerance  |NULL                                         |NULL                                         |
# |AllergyIntolerance  |NULL                                         |NULL                                         |
# |AllergyIntolerance  |NULL                                         |NULL                                         |
# |MedicationRequest   |urn:uuid:473282d3-65db-fb8e-9913-af83bbf2595f|urn:uuid:473282d3-65db-fb8e-ae22-2d4ba5c093db|
# |Claim               |NULL                                         |NULL                                         |
# |ExplanationOfBenefit|NULL                                         |NULL                                         |
# |MedicationRequest   |urn:uuid:473282d3-65db-fb8e-9913-af83bbf2595f|urn:uuid:473282d3-65db-fb8e-ae22-2d4ba5c093db|
# |Claim               |NULL                                         |NULL                                         |
# |ExplanationOfBenefit|NULL                                         |NULL                                         |
# |DiagnosticReport    |urn:uuid:473282d3-65db-fb8e-9913-af83bbf2595f|urn:uuid:473282d3-65db-fb8e-ae22-2d4ba5c093db|
# +--------------------+---------------------------------------------+---------------------------------------------+
# only showing top 20 rows

# %% [markdown]
# ✅ Safer UC-friendly version (recommended)
#
#
# Some FHIR resources do not have subject or encounter, so use this:
#
#
# ✔ Same logic
# ✔ Cleaner output
# ✔ Avoids confusion when values are null

# %%
exploded_df.select(
    col("entry.resource.resourceType").alias("resource_type"),
    col("entry.resource.subject.reference").alias("subject_ref"),
    col("entry.resource.encounter.reference").alias("encounter_ref")
).show(20, truncate=False)
# Out:
# +--------------------+---------------------------------------------+---------------------------------------------+
# |resource_type       |subject_ref                                  |encounter_ref                                |
# +--------------------+---------------------------------------------+---------------------------------------------+
# |Patient             |NULL                                         |NULL                                         |
# |Encounter           |urn:uuid:473282d3-65db-fb8e-9913-af83bbf2595f|NULL                                         |
# |CareTeam            |urn:uuid:473282d3-65db-fb8e-9913-af83bbf2595f|urn:uuid:473282d3-65db-fb8e-043f-ee22ffdc488c|
# |CarePlan            |urn:uuid:473282d3-65db-fb8e-9913-af83bbf2595f|urn:uuid:473282d3-65db-fb8e-043f-ee22ffdc488c|
# |DiagnosticReport    |urn:uuid:473282d3-65db-fb8e-9913-af83bbf2595f|urn:uuid:473282d3-65db-fb8e-043f-ee22ffdc488c|
# |DocumentReference   |urn:uuid:473282d3-65db-fb8e-9913-af83bbf2595f|NULL                                         |
# |Claim               |NULL                                         |NULL                                         |
# |ExplanationOfBenefit|NULL                                         |NULL                                         |
# |Encounter           |urn:uuid:473282d3-65db-fb8e-9913-af83bbf2595f|NULL                                         |
# |AllergyIntolerance  |NULL                                         |NULL                                         |
# |AllergyIntolerance  |NULL                                         |NULL                                         |
# |AllergyIntolerance  |NULL                                         |NULL                                         |
# |AllergyIntolerance  |NULL                                         |NULL                                         |
# |MedicationRequest   |urn:uuid:473282d3-65db-fb8e-9913-af83bbf2595f|urn:uuid:473282d3-65db-fb8e-ae22-2d4ba5c093db|
# |Claim               |NULL                                         |NULL                                         |
# |ExplanationOfBenefit|NULL                                         |NULL                                         |
# |MedicationRequest   |urn:uuid:473282d3-65db-fb8e-9913-af83bbf2595f|urn:uuid:473282d3-65db-fb8e-ae22-2d4ba5c093db|
# |Claim               |NULL                                         |NULL                                         |
# |ExplanationOfBenefit|NULL                                         |NULL                                         |
# |DiagnosticReport    |urn:uuid:473282d3-65db-fb8e-9913-af83bbf2595f|urn:uuid:473282d3-65db-fb8e-ae22-2d4ba5c093db|
# +--------------------+---------------------------------------------+---------------------------------------------+
# only showing top 20 rows

# %% [markdown]
# 7️⃣ STEP 8 – Schema drift detection (✅ OK)
#
#
# ✔ Correct
# ✔ This huge schema is EXPECTED for FHIR
# ✔ Bronze must accept it

# %%
bronze_df.printSchema()
# Out:
# root
#  |-- entry: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- fullUrl: string (nullable = true)
#  |    |    |-- request: struct (nullable = true)
#  |    |    |    |-- ifNoneExist: string (nullable = true)
#  |    |    |    |-- method: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- resource: struct (nullable = true)
#  |    |    |    |-- abatementDateTime: string (nullable = true)
#  |    |    |    |-- active: boolean (nullable = true)
#  |    |    |    |-- activity: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- detail: struct (nullable = true)
#  |    |    |    |    |    |    |-- code: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |    |-- location: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |-- reasonCode: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |    |-- reasonReference: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |    |    |    |-- status: string (nullable = true)
#  |    |    |    |-- address: string (nullable = true)
#  |    |    |    |-- addresses: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- agent: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- onBehalfOf: struct (nullable = true)
#  |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |    |    |-- type: struct (nullable = true)
#  |    |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |-- who: struct (nullable = true)
#  |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- author: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- authoredOn: string (nullable = true)
#  |    |    |    |-- billablePeriod: struct (nullable = true)
#  |    |    |    |    |-- end: string (nullable = true)
#  |    |    |    |    |-- start: string (nullable = true)
#  |    |    |    |-- birthDate: string (nullable = true)
#  |    |    |    |-- careTeam: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- provider: struct (nullable = true)
#  |    |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |    |    |-- role: struct (nullable = true)
#  |    |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- sequence: long (nullable = true)
#  |    |    |    |-- category: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- claim: struct (nullable = true)
#  |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- class: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |-- clinicalStatus: struct (nullable = true)
#  |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |-- code: string (nullable = true)
#  |    |    |    |-- communication: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- language: struct (nullable = true)
#  |    |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |-- component: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- code: struct (nullable = true)
#  |    |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |-- valueCodeableConcept: struct (nullable = true)
#  |    |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |-- valueQuantity: struct (nullable = true)
#  |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |-- unit: string (nullable = true)
#  |    |    |    |    |    |    |-- value: double (nullable = true)
#  |    |    |    |    |    |-- valueString: string (nullable = true)
#  |    |    |    |-- contained: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- beneficiary: struct (nullable = true)
#  |    |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |    |-- intent: string (nullable = true)
#  |    |    |    |    |    |-- payor: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |-- performer: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |    |    |-- requester: struct (nullable = true)
#  |    |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |    |    |-- resourceType: string (nullable = true)
#  |    |    |    |    |    |-- status: string (nullable = true)
#  |    |    |    |    |    |-- subject: struct (nullable = true)
#  |    |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |    |    |-- type: struct (nullable = true)
#  |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |-- content: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- attachment: struct (nullable = true)
#  |    |    |    |    |    |    |-- contentType: string (nullable = true)
#  |    |    |    |    |    |    |-- data: string (nullable = true)
#  |    |    |    |    |    |-- format: struct (nullable = true)
#  |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |-- context: struct (nullable = true)
#  |    |    |    |    |-- encounter: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |    |-- period: struct (nullable = true)
#  |    |    |    |    |    |-- end: string (nullable = true)
#  |    |    |    |    |    |-- start: string (nullable = true)
#  |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- created: string (nullable = true)
#  |    |    |    |-- criticality: string (nullable = true)
#  |    |    |    |-- custodian: struct (nullable = true)
#  |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- date: string (nullable = true)
#  |    |    |    |-- deceasedDateTime: string (nullable = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |    |    |-- deviceName: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- diagnosis: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- diagnosisReference: struct (nullable = true)
#  |    |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |    |    |-- sequence: long (nullable = true)
#  |    |    |    |    |    |-- type: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |-- distinctIdentifier: string (nullable = true)
#  |    |    |    |-- dosage: struct (nullable = true)
#  |    |    |    |    |-- dose: struct (nullable = true)
#  |    |    |    |    |    |-- value: double (nullable = true)
#  |    |    |    |    |-- rateQuantity: struct (nullable = true)
#  |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |-- dosageInstruction: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- additionalInstruction: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |-- asNeededBoolean: boolean (nullable = true)
#  |    |    |    |    |    |-- doseAndRate: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- doseQuantity: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- value: double (nullable = true)
#  |    |    |    |    |    |    |    |-- type: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- sequence: long (nullable = true)
#  |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |-- timing: struct (nullable = true)
#  |    |    |    |    |    |    |-- repeat: struct (nullable = true)
#  |    |    |    |    |    |    |    |-- frequency: long (nullable = true)
#  |    |    |    |    |    |    |    |-- period: double (nullable = true)
#  |    |    |    |    |    |    |    |-- periodUnit: string (nullable = true)
#  |    |    |    |-- effectiveDateTime: string (nullable = true)
#  |    |    |    |-- encounter: struct (nullable = true)
#  |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- expirationDate: string (nullable = true)
#  |    |    |    |-- extension: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- extension: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |    |-- valueCoding: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |    |-- valueString: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |-- valueAddress: struct (nullable = true)
#  |    |    |    |    |    |    |-- city: string (nullable = true)
#  |    |    |    |    |    |    |-- country: string (nullable = true)
#  |    |    |    |    |    |    |-- state: string (nullable = true)
#  |    |    |    |    |    |-- valueCode: string (nullable = true)
#  |    |    |    |    |    |-- valueDecimal: double (nullable = true)
#  |    |    |    |    |    |-- valueInteger: long (nullable = true)
#  |    |    |    |    |    |-- valueString: string (nullable = true)
#  |    |    |    |-- facility: struct (nullable = true)
#  |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- gender: string (nullable = true)
#  |    |    |    |-- hospitalization: struct (nullable = true)
#  |    |    |    |    |-- dischargeDisposition: struct (nullable = true)
#  |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |-- id: string (nullable = true)
#  |    |    |    |-- identifier: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- type: struct (nullable = true)
#  |    |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |-- use: string (nullable = true)
#  |    |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- insurance: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- coverage: struct (nullable = true)
#  |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |    |    |-- focal: boolean (nullable = true)
#  |    |    |    |    |    |-- sequence: long (nullable = true)
#  |    |    |    |-- insurer: struct (nullable = true)
#  |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |-- intent: string (nullable = true)
#  |    |    |    |-- issued: string (nullable = true)
#  |    |    |    |-- item: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- adjudication: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- amount: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- currency: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- value: double (nullable = true)
#  |    |    |    |    |    |    |    |-- category: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- category: struct (nullable = true)
#  |    |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- diagnosisSequence: array (nullable = true)
#  |    |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |    |-- encounter: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |    |    |-- informationSequence: array (nullable = true)
#  |    |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |    |-- locationCodeableConcept: struct (nullable = true)
#  |    |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- net: struct (nullable = true)
#  |    |    |    |    |    |    |-- currency: string (nullable = true)
#  |    |    |    |    |    |    |-- value: double (nullable = true)
#  |    |    |    |    |    |-- procedureSequence: array (nullable = true)
#  |    |    |    |    |    |    |-- element: long (containsNull = true)
#  |    |    |    |    |    |-- productOrService: struct (nullable = true)
#  |    |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |-- sequence: long (nullable = true)
#  |    |    |    |    |    |-- servicedPeriod: struct (nullable = true)
#  |    |    |    |    |    |    |-- end: string (nullable = true)
#  |    |    |    |    |    |    |-- start: string (nullable = true)
#  |    |    |    |-- location: string (nullable = true)
#  |    |    |    |-- lotNumber: string (nullable = true)
#  |    |    |    |-- managingOrganization: string (nullable = true)
#  |    |    |    |-- manufactureDate: string (nullable = true)
#  |    |    |    |-- maritalStatus: struct (nullable = true)
#  |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |-- medicationCodeableConcept: struct (nullable = true)
#  |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |-- medicationReference: struct (nullable = true)
#  |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- meta: struct (nullable = true)
#  |    |    |    |    |-- profile: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- mode: string (nullable = true)
#  |    |    |    |-- multipleBirthBoolean: boolean (nullable = true)
#  |    |    |    |-- multipleBirthInteger: long (nullable = true)
#  |    |    |    |-- name: string (nullable = true)
#  |    |    |    |-- numberOfInstances: long (nullable = true)
#  |    |    |    |-- numberOfSeries: long (nullable = true)
#  |    |    |    |-- occurrenceDateTime: string (nullable = true)
#  |    |    |    |-- onsetDateTime: string (nullable = true)
#  |    |    |    |-- organization: struct (nullable = true)
#  |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |-- identifier: struct (nullable = true)
#  |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- outcome: string (nullable = true)
#  |    |    |    |-- participant: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- individual: struct (nullable = true)
#  |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |    |    |-- member: struct (nullable = true)
#  |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |    |    |-- period: struct (nullable = true)
#  |    |    |    |    |    |    |-- end: string (nullable = true)
#  |    |    |    |    |    |    |-- start: string (nullable = true)
#  |    |    |    |    |    |-- role: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |-- type: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |-- patient: struct (nullable = true)
#  |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- payment: struct (nullable = true)
#  |    |    |    |    |-- amount: struct (nullable = true)
#  |    |    |    |    |    |-- currency: string (nullable = true)
#  |    |    |    |    |    |-- value: double (nullable = true)
#  |    |    |    |-- performedPeriod: struct (nullable = true)
#  |    |    |    |    |-- end: string (nullable = true)
#  |    |    |    |    |-- start: string (nullable = true)
#  |    |    |    |-- performer: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- period: struct (nullable = true)
#  |    |    |    |    |-- end: string (nullable = true)
#  |    |    |    |    |-- start: string (nullable = true)
#  |    |    |    |-- physicalType: struct (nullable = true)
#  |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |-- position: struct (nullable = true)
#  |    |    |    |    |-- latitude: double (nullable = true)
#  |    |    |    |    |-- longitude: double (nullable = true)
#  |    |    |    |-- practitioner: struct (nullable = true)
#  |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |-- identifier: struct (nullable = true)
#  |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- prescription: struct (nullable = true)
#  |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- presentedForm: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- contentType: string (nullable = true)
#  |    |    |    |    |    |-- data: string (nullable = true)
#  |    |    |    |-- primarySource: boolean (nullable = true)
#  |    |    |    |-- priority: struct (nullable = true)
#  |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |-- procedure: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- procedureReference: struct (nullable = true)
#  |    |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |    |    |-- sequence: long (nullable = true)
#  |    |    |    |-- procedureCode: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |-- provider: struct (nullable = true)
#  |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- reaction: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- manifestation: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |    |-- severity: string (nullable = true)
#  |    |    |    |-- reasonCode: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |-- reasonReference: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- recorded: string (nullable = true)
#  |    |    |    |-- recordedDate: string (nullable = true)
#  |    |    |    |-- referral: struct (nullable = true)
#  |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- requester: struct (nullable = true)
#  |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- resourceType: string (nullable = true)
#  |    |    |    |-- result: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- serialNumber: string (nullable = true)
#  |    |    |    |-- series: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- bodySite: struct (nullable = true)
#  |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- instance: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- number: long (nullable = true)
#  |    |    |    |    |    |    |    |-- sopClass: struct (nullable = true)
#  |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |    |    |-- title: string (nullable = true)
#  |    |    |    |    |    |    |    |-- uid: string (nullable = true)
#  |    |    |    |    |    |-- modality: struct (nullable = true)
#  |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- number: long (nullable = true)
#  |    |    |    |    |    |-- numberOfInstances: long (nullable = true)
#  |    |    |    |    |    |-- started: string (nullable = true)
#  |    |    |    |    |    |-- uid: string (nullable = true)
#  |    |    |    |-- serviceProvider: struct (nullable = true)
#  |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- specialty: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |-- started: string (nullable = true)
#  |    |    |    |-- status: string (nullable = true)
#  |    |    |    |-- subject: struct (nullable = true)
#  |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- suppliedItem: struct (nullable = true)
#  |    |    |    |    |-- itemCodeableConcept: struct (nullable = true)
#  |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |    |-- quantity: struct (nullable = true)
#  |    |    |    |    |    |-- value: long (nullable = true)
#  |    |    |    |-- supportingInfo: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- category: struct (nullable = true)
#  |    |    |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- sequence: long (nullable = true)
#  |    |    |    |    |    |-- valueReference: struct (nullable = true)
#  |    |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- target: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- reference: string (nullable = true)
#  |    |    |    |-- telecom: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- extension: array (nullable = true)
#  |    |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |    |    |    |-- valueBoolean: boolean (nullable = true)
#  |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |    |-- use: string (nullable = true)
#  |    |    |    |    |    |-- value: string (nullable = true)
#  |    |    |    |-- text: struct (nullable = true)
#  |    |    |    |    |-- div: string (nullable = true)
#  |    |    |    |    |-- status: string (nullable = true)
#  |    |    |    |-- total: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- udiCarrier: array (nullable = true)
#  |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |-- carrierHRF: string (nullable = true)
#  |    |    |    |    |    |-- deviceIdentifier: string (nullable = true)
#  |    |    |    |-- use: string (nullable = true)
#  |    |    |    |-- vaccineCode: struct (nullable = true)
#  |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |-- valueCodeableConcept: struct (nullable = true)
#  |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |-- display: string (nullable = true)
#  |    |    |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |-- text: string (nullable = true)
#  |    |    |    |-- valueQuantity: struct (nullable = true)
#  |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |-- system: string (nullable = true)
#  |    |    |    |    |-- unit: string (nullable = true)
#  |    |    |    |    |-- value: double (nullable = true)
#  |    |    |    |-- valueString: string (nullable = true)
#  |    |    |    |-- verificationStatus: struct (nullable = true)
#  |    |    |    |    |-- coding: array (nullable = true)
#  |    |    |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |    |    |-- code: string (nullable = true)
#  |    |    |    |    |    |    |-- system: string (nullable = true)
#  |-- resourceType: string (nullable = true)
#  |-- type: string (nullable = true)
#  |-- source_file: string (nullable = true)
#  |-- ingest_time: timestamp (nullable = true)

# %% [markdown]
# 8️⃣ STEP 9 – Create Bronze exploded VIEW (✅ OK, UC compatible)
#
# Your SQL is correct for Unity Catalog:
#
#
# ✔ View (no storage)
# ✔ UC-governed
# ✔ Perfect for Silver input

# %%
# %sql
CREATE OR REPLACE VIEW angad_kumar91.fhir_healthcare_analytics_bronze.fhir_entry_view AS
SELECT
  source_file,
  ingest_time,
  explode(entry) AS entry
FROM angad_kumar91.fhir_healthcare_analytics_bronze.fhir_bundle;

# %% [markdown]
# 9️⃣ STEP 10 – Validate Bronze VIEW (✅ OK)
#
#
# ✔ Correct
# ✔ Final Bronze validation
# ✔ Confirms ingestion correctness

# %%
# %sql
SELECT
  entry.resource.resourceType,
  COUNT(*) AS cnt
FROM angad_kumar91.fhir_healthcare_analytics_bronze.fhir_entry_view
GROUP BY entry.resource.resourceType
ORDER BY cnt DESC;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>resourceType</th><th>cnt</th></tr></thead><tbody><tr><td>Observation</td><td>64987</td></tr><tr><td>Procedure</td><td>20153</td></tr><tr><td>DiagnosticReport</td><td>14488</td></tr><tr><td>Claim</td><td>12902</td></tr><tr><td>ExplanationOfBenefit</td><td>12902</td></tr><tr><td>DocumentReference</td><td>7095</td></tr><tr><td>Encounter</td><td>7095</td></tr><tr><td>MedicationRequest</td><td>5807</td></tr><tr><td>Condition</td><td>4516</td></tr><tr><td>SupplyDelivery</td><td>2844</td></tr><tr><td>Immunization</td><td>1582</td></tr><tr><td>Medication</td><td>1480</td></tr><tr><td>MedicationAdministration</td><td>1480</td></tr><tr><td>Device</td><td>678</td></tr><tr><td>ImagingStudy</td><td>631</td></tr><tr><td>CareTeam</td><td>392</td></tr><tr><td>CarePlan</td><td>392</td></tr><tr><td>Location</td><td>290</td></tr><tr><td>Organization</td><td>289</td></tr><tr><td>Practitioner</td><td>289</td></tr><tr><td>PractitionerRole</td><td>289</td></tr><tr><td>AllergyIntolerance</td><td>149</td></tr><tr><td>Provenance</td><td>115</td></tr><tr><td>Patient</td><td>115</td></tr></tbody></table></div>

# %% [markdown]
# 🧾 FINAL CLEAN VERSION (YOU CAN KEEP THIS)
#
# If you want a single clean reference, this is the final UC-correct Bronze working sequence:

# %%
bronze_df = spark.table(
    "angad_kumar91.fhir_healthcare_analytics_bronze.fhir_bundle"
)

bronze_df.selectExpr("size(entry) as resource_count").show(10)

from pyspark.sql.functions import explode, col

exploded_df = bronze_df.select(
    col("source_file"),
    col("ingest_time"),
    explode("entry").alias("entry")
)

exploded_df.select(
    col("entry.resource.resourceType").alias("resource_type"),
    col("entry.resource.subject.reference").alias("subject_ref"),
    col("entry.resource.encounter.reference").alias("encounter_ref")
).show(20, truncate=False)
# Out:
# +--------------+
# |resource_count|
# +--------------+
# |           440|
# |          2455|
# |           358|
# |          1060|
# |           398|
# |           309|
# |           480|
# |           758|
# |           674|
# |           843|
# +--------------+
# only showing top 10 rows
# +--------------------+---------------------------------------------+---------------------------------------------+
# |resource_type       |subject_ref                                  |encounter_ref                                |
# +--------------------+---------------------------------------------+---------------------------------------------+
# |Patient             |NULL                                         |NULL                                         |
# |Encounter           |urn:uuid:473282d3-65db-fb8e-9913-af83bbf2595f|NULL                                         |
# |CareTeam            |urn:uuid:473282d3-65db-fb8e-9913-af83bbf2595f|urn:uuid:473282d3-65db-fb8e-043f-ee22ffdc488c|
# |CarePlan            |urn:uuid:473282d3-65db-fb8e-9913-af83bbf2595f|urn:uuid:473282d3-65db-fb8e-043f-ee22ffdc488c|
# |DiagnosticReport    |urn:uuid:473282d3-65db-fb8e-9913-af83bbf2595f|urn:uuid:473282d3-65db-fb8e-043f-ee22ffdc488c|
# |DocumentReference   |urn:uuid:473282d3-65db-fb8e-9913-af83bbf2595f|NULL                                         |
# |Claim               |NULL                                         |NULL                                         |
# |ExplanationOfBenefit|NULL                                         |NULL                                         |
# |Encounter           |urn:uuid:473282d3-65db-fb8e-9913-af83bbf2595f|NULL                                         |
# |AllergyIntolerance  |NULL                                         |NULL                                         |
# |AllergyIntolerance  |NULL                                         |NULL                                         |
# |AllergyIntolerance  |NULL                                         |NULL                                         |
# |AllergyIntolerance  |NULL                                         |NULL                                         |
# |MedicationRequest   |urn:uuid:473282d3-65db-fb8e-9913-af83bbf2595f|urn:uuid:473282d3-65db-fb8e-ae22-2d4ba5c093db|
# |Claim               |NULL                                         |NULL                                         |
# |ExplanationOfBenefit|NULL                                         |NULL                                         |
# |MedicationRequest   |urn:uuid:473282d3-65db-fb8e-9913-af83bbf2595f|urn:uuid:473282d3-65db-fb8e-ae22-2d4ba5c093db|
# |Claim               |NULL                                         |NULL                                         |
# |ExplanationOfBenefit|NULL                                         |NULL                                         |
# |DiagnosticReport    |urn:uuid:473282d3-65db-fb8e-9913-af83bbf2595f|urn:uuid:473282d3-65db-fb8e-ae22-2d4ba5c093db|
# +--------------------+---------------------------------------------+---------------------------------------------+
# only showing top 20 rows

# %% [markdown]
# 🧠 Final confirmation
#
# ✅ Your Bronze layer is now complete and correct
#
# ✅ Unity Catalog–compliant
#
# ✅ Medallion-aligned
#
# ✅ Healthcare-grade
